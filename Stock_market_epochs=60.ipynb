# %% [markdown]
# <a href="https://colab.research.google.com/github/AV-016/Research-on-LSTM/blob/main/Stock_market_epochs%3D60.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import yfinance as yf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# Tickers to analyze
tickers = ['AAPL', 'MSFT', 'GOOGL', 'AMZN']

# Settings
window_size = 60
forecast_horizon = 7  # Predict 7 days ahead
epochs = 60
batch_size = 32

def prepare_data(df):
    df = df[['Close', 'High', 'Low', 'Volume']]
    scaler = MinMaxScaler()
    scaled_data = scaler.fit_transform(df)

    X, y = [], []
    for i in range(window_size, len(scaled_data) - forecast_horizon + 1):
        X.append(scaled_data[i - window_size:i])
        y.append([scaled_data[i + j][0] for j in range(forecast_horizon)])

    X, y = np.array(X), np.array(y)

    split = int(0.8 * len(X))
    X_train, X_test = X[:split], X[split:]
    y_train, y_test = y[:split], y[split:]

    return X_train, X_test, y_train, y_test, scaler

def build_model(input_shape):
    model = Sequential()
    model.add(LSTM(units=50, return_sequences=False, input_shape=input_shape))
    model.add(Dense(forecast_horizon))
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

def inverse_transform(batch, scaler):
    padded = np.zeros((len(batch), 4))
    padded[:, 0] = batch
    return scaler.inverse_transform(padded)[:, 0]

# Initialize results list for saving
results = []

for ticker in tickers:
    print(f"\n📈 Processing {ticker}...\n")
    df = yf.download(ticker, start='2020-01-01', end='2024-12-31')
    X_train, X_test, y_train, y_test, scaler = prepare_data(df)

    model = build_model((X_train.shape[1], X_train.shape[2]))
    model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, verbose=1)

    # Predict
    predicted = model.predict(X_test)

    # Calculate RMSE and MAPE for 1-day and 7-day predictions
    rmse_list, mape_list = [], []

    for day in range(forecast_horizon):
        true_vals = inverse_transform(y_test[:, day], scaler)
        pred_vals = inverse_transform(predicted[:, day], scaler)
        rmse = np.sqrt(mean_squared_error(true_vals, pred_vals))
        mape = mean_absolute_percentage_error(true_vals, pred_vals) * 100
        rmse_list.append(rmse)
        mape_list.append(mape)

        # Plot for each day
        plt.figure(figsize=(10, 4))
        plt.plot(true_vals, label='True Price')
        plt.plot(pred_vals, label='Predicted Price')
        plt.title(f'{ticker} - Day {day + 1} Ahead Forecast')
        plt.xlabel('Time')
        plt.ylabel('Price')
        plt.legend()
        plt.tight_layout()
        plt.show()

    # Store results for the current ticker
    avg_rmse_1day = rmse_list[0]  # RMSE for 1-day
    avg_mape_1day = mape_list[0]  # MAPE for 1-day
    avg_rmse_7day = np.mean(rmse_list)  # Average RMSE for 7-day
    avg_mape_7day = np.mean(mape_list)  # Average MAPE for 7-day

    results.append([ticker, avg_rmse_1day, avg_mape_1day, avg_rmse_7day, avg_mape_7day])

    print(f"📊 {ticker} RMSE (1-day): {avg_rmse_1day:.4f}")
    print(f"📊 {ticker} MAPE (1-day): {avg_mape_1day:.2f}%")
    print(f"📊 {ticker} RMSE (7-day): {avg_rmse_7day:.4f}")
    print(f"📊 {ticker} MAPE (7-day): {avg_mape_7day:.2f}%")

# Create a DataFrame to display the results
results_df = pd.DataFrame(results, columns=['Ticker', '1-Day RMSE', '1-Day MAPE (%)', '7-Day RMSE', '7-Day MAPE (%)'])

# Save the table as a CSV file
results_df.to_csv('stock_price_predictions_results.csv', index=False)

# Display the table in the notebook
print("\n📊 Evaluation Results (RMSE & MAPE):")
print(results_df)
# Out:
# 📈 Processing AAPL...
#
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 44ms/step - loss: 0.0852
# Epoch 2/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0028
# Epoch 3/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0013
# Epoch 4/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0010
# Epoch 5/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 9.8993e-04
# Epoch 6/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 9.9990e-04
# Epoch 7/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0010
# Epoch 8/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 9.6320e-04
# Epoch 9/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 9.8558e-04
# Epoch 10/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 9.0970e-04
# Epoch 11/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 9.9139e-04
# Epoch 12/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 9.4612e-04
# Epoch 13/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 8.9905e-04
# Epoch 14/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 9.8989e-04
# Epoch 15/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 9.3001e-04
# Epoch 16/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 9.0613e-04
# Epoch 17/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 9.2486e-04
# Epoch 18/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 9.1845e-04
# Epoch 19/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 8.3887e-04
# Epoch 20/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 8.5519e-04
# Epoch 21/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 8.2241e-04
# Epoch 22/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 8.8770e-04
# Epoch 23/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 8.5792e-04
# Epoch 24/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 8.6009e-04
# Epoch 25/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 9.1038e-04
# Epoch 26/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 8.0602e-04
# Epoch 27/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 8.2544e-04
# Epoch 28/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 7.8962e-04
# Epoch 29/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 8.2307e-04
# Epoch 30/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 7.9354e-04
# Epoch 31/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 8.0116e-04
# Epoch 32/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 8.0178e-04
# Epoch 33/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 8.2743e-04
# Epoch 34/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 8.1669e-04
# Epoch 35/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 8.3939e-04
# Epoch 36/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 7.7213e-04
# Epoch 37/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 7.7659e-04
# Epoch 38/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 8.0090e-04
# Epoch 39/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 7.8308e-04
# Epoch 40/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 8.0028e-04
# Epoch 41/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 7.7902e-04
# Epoch 42/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 7.2796e-04
# Epoch 43/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 7.4202e-04
# Epoch 44/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 7.5419e-04
# Epoch 45/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 7.1644e-04
# Epoch 46/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 7.8549e-04
# Epoch 47/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 7.1307e-04
# Epoch 48/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 7.5919e-04
# Epoch 49/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 7.4343e-04
# Epoch 50/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 7.6291e-04
# Epoch 51/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 6.7965e-04
# Epoch 52/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 7.5974e-04
# Epoch 53/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 6.8471e-04
# Epoch 54/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 7.2232e-04
# Epoch 55/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 7.6451e-04
# Epoch 56/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 6.9661e-04
# Epoch 57/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 6.8475e-04
# Epoch 58/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 7.3101e-04
# Epoch 59/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 7.3334e-04
# Epoch 60/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 7.2190e-04
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 📊 AAPL RMSE (1-day): 4.8543
# 📊 AAPL MAPE (1-day): 1.85%
# 📊 AAPL RMSE (7-day): 8.2269
# 📊 AAPL MAPE (7-day): 3.08%
#
# 📈 Processing MSFT...
# [*********************100%***********************]  1 of 1 completed
# Epoch 1/60
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.0757
# Epoch 2/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0036
# Epoch 3/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0013
# Epoch 4/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0011
# Epoch 5/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0010
# Epoch 6/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0011
# Epoch 7/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 9.9676e-04
# Epoch 8/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0010
# Epoch 9/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 9.7996e-04
# Epoch 10/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 9.1950e-04
# Epoch 11/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0010
# Epoch 12/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 9.6294e-04
# Epoch 13/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0010
# Epoch 14/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 9.6306e-04
# Epoch 15/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 9.6904e-04
# Epoch 16/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 8.9638e-04
# Epoch 17/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 9.4248e-04
# Epoch 18/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 9.0150e-04
# Epoch 19/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 9.5776e-04
# Epoch 20/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 9.1924e-04
# Epoch 21/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 9.7259e-04
# Epoch 22/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 8.2875e-04
# Epoch 23/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 8.4714e-04
# Epoch 24/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 8.9130e-04
# Epoch 25/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 8.5675e-04
# Epoch 26/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 7.6649e-04
# Epoch 27/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 8.2159e-04
# Epoch 28/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 8.3448e-04
# Epoch 29/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 7.9967e-04
# Epoch 30/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 7.9858e-04
# Epoch 31/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 8.3394e-04
# Epoch 32/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 8.1140e-04
# Epoch 33/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 8.3729e-04
# Epoch 34/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 8.0670e-04
# Epoch 35/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 8.1623e-04
# Epoch 36/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 7.9863e-04
# Epoch 37/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 8.8199e-04
# Epoch 38/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 7.5922e-04
# Epoch 39/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 7.8998e-04
# Epoch 40/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 7.9678e-04
# Epoch 41/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 7.9277e-04
# Epoch 42/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 8.1048e-04
# Epoch 43/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 7.2140e-04
# Epoch 44/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 7.8053e-04
# Epoch 45/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 7.8899e-04
# Epoch 46/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 7.9003e-04
# Epoch 47/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 7.4234e-04
# Epoch 48/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 7.6211e-04
# Epoch 49/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 7.4611e-04
# Epoch 50/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 7.6976e-04
# Epoch 51/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 8.2696e-04
# Epoch 52/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 7.5209e-04
# Epoch 53/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 7.4539e-04
# Epoch 54/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 7.4536e-04
# Epoch 55/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 6.8955e-04
# Epoch 56/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 7.5893e-04
# Epoch 57/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 7.6835e-04
# Epoch 58/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 7.3453e-04
# Epoch 59/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 7.4141e-04
# Epoch 60/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 7.5099e-04
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# [*********************100%***********************]  1 of 1 completed
# 📊 MSFT RMSE (1-day): 7.2722
# 📊 MSFT MAPE (1-day): 1.43%
# 📊 MSFT RMSE (7-day): 10.9887
# 📊 MSFT MAPE (7-day): 2.20%
#
# 📈 Processing GOOGL...
#
# Epoch 1/60
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - loss: 0.0925
# Epoch 2/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0032
# Epoch 3/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0015
# Epoch 4/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0013
# Epoch 5/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0014
# Epoch 6/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0013
# Epoch 7/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0013
# Epoch 8/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0012
# Epoch 9/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0012
# Epoch 10/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0013
# Epoch 11/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0013
# Epoch 12/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0012
# Epoch 13/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0012
# Epoch 14/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0013
# Epoch 15/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0012
# Epoch 16/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0012
# Epoch 17/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0011
# Epoch 18/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0011
# Epoch 19/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0013
# Epoch 20/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0012
# Epoch 21/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0011
# Epoch 22/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0012
# Epoch 23/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0010
# Epoch 24/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0011
# Epoch 25/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - loss: 0.0010
# Epoch 26/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0011
# Epoch 27/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0011
# Epoch 28/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0011
# Epoch 29/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0011
# Epoch 30/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0011
# Epoch 31/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0010
# Epoch 32/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0011
# Epoch 33/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 9.8758e-04
# Epoch 34/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0011
# Epoch 35/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 9.9445e-04
# Epoch 36/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.0010
# Epoch 37/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 9.5516e-04
# Epoch 38/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 9.9328e-04
# Epoch 39/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 9.7179e-04
# Epoch 40/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 9.6804e-04
# Epoch 41/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0010
# Epoch 42/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0010
# Epoch 43/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 9.9054e-04
# Epoch 44/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 9.6629e-04
# Epoch 45/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 9.3524e-04
# Epoch 46/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 9.2825e-04
# Epoch 47/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 9.7793e-04
# Epoch 48/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 9.3296e-04
# Epoch 49/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 9.6355e-04
# Epoch 50/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 9.4621e-04
# Epoch 51/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 9.6361e-04
# Epoch 52/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 9.7232e-04
# Epoch 53/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 9.0010e-04
# Epoch 54/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 9.1302e-04
# Epoch 55/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 9.2350e-04
# Epoch 56/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 8.8907e-04
# Epoch 57/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 9.1916e-04
# Epoch 58/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 8.9478e-04
# Epoch 59/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 9.3120e-04
# Epoch 60/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 8.9649e-04
# WARNING:tensorflow:5 out of the last 17 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7e69fa633560> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step
# [*********************100%***********************]  1 of 1 completed
# 📊 GOOGL RMSE (1-day): 4.1924
# 📊 GOOGL MAPE (1-day): 1.95%
# 📊 GOOGL RMSE (7-day): 6.1168
# 📊 GOOGL MAPE (7-day): 2.92%
#
# 📈 Processing AMZN...
#
# Epoch 1/60
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 0.1118
# Epoch 2/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0057
# Epoch 3/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0031
# Epoch 4/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0031
# Epoch 5/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0028
# Epoch 6/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0027
# Epoch 7/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0026
# Epoch 8/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 0.0027
# Epoch 9/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0026
# Epoch 10/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0027
# Epoch 11/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0027
# Epoch 12/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0025
# Epoch 13/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0024
# Epoch 14/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0024
# Epoch 15/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0023
# Epoch 16/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0025
# Epoch 17/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0023
# Epoch 18/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0023
# Epoch 19/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0025
# Epoch 20/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0023
# Epoch 21/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0022
# Epoch 22/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0020
# Epoch 23/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0022
# Epoch 24/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0022
# Epoch 25/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0020
# Epoch 26/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0022
# Epoch 27/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0020
# Epoch 28/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0020
# Epoch 29/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0022
# Epoch 30/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0021
# Epoch 31/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 0.0020
# Epoch 32/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0020
# Epoch 33/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0021
# Epoch 34/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0019
# Epoch 35/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0020
# Epoch 36/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0020
# Epoch 37/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0019
# Epoch 38/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0021
# Epoch 39/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0019
# Epoch 40/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0020
# Epoch 41/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0020
# Epoch 42/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0019
# Epoch 43/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0020
# Epoch 44/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0020
# Epoch 45/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0019
# Epoch 46/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0020
# Epoch 47/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0019
# Epoch 48/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0019
# Epoch 49/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0019
# Epoch 50/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0018
# Epoch 51/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0019
# Epoch 52/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0018
# Epoch 53/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0017
# Epoch 54/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0018
# Epoch 55/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0018
# Epoch 56/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0019
# Epoch 57/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0018
# Epoch 58/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0019
# Epoch 59/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0018
# Epoch 60/60
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0018
# WARNING:tensorflow:5 out of the last 17 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7e69fce53240> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 📊 AMZN RMSE (1-day): 4.7619
# 📊 AMZN MAPE (1-day): 1.99%
# 📊 AMZN RMSE (7-day): 8.6920
# 📊 AMZN MAPE (7-day): 3.64%
#
# 📊 Evaluation Results (RMSE & MAPE):
#   Ticker  1-Day RMSE  1-Day MAPE (%)  7-Day RMSE  7-Day MAPE (%)
# 0   AAPL    4.854328        1.847991    8.226874        3.083156
# 1   MSFT    7.272204        1.427519   10.988697        2.204402
# 2  GOOGL    4.192417        1.947968    6.116774        2.919915
# 3   AMZN    4.761905        1.993386    8.691964        3.637291
